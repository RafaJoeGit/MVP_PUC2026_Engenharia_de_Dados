-- %%
 SELECT
    neighbourhood_cleansed AS bairro,
    quantidade_anuncios,
    ROUND(preco_medio, 2) AS preco_medio
FROM workspace.default.gold_neighbourhood_price
ORDER BY preco_medio DESC;
-- Out:
-- Databricks visualization. Run in Databricks to view.
