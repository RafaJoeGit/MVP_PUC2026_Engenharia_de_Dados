# %%
 tabelas = spark.sql("SHOW TABLES IN workspace.default").collect()

for t in tabelas:
    nome = t["tableName"]
    total = spark.table(f"workspace.default.{nome}").count()
    print(f"{nome}: {total} registros")
