-- %%
 SELECT
    'listing_id' AS atributo,
    'bigint' AS tipo,
    COUNT(*) AS total_registros,
    COUNT(*) - COUNT(listing_id) AS nulos,
    COUNT(DISTINCT listing_id) AS distintos,
    CAST(MIN(listing_id) AS STRING) AS minimo,
    CAST(MAX(listing_id) AS STRING) AS maximo
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'neighbourhood_key',
    'int',
    COUNT(*),
    COUNT(*) - COUNT(neighbourhood_key),
    COUNT(DISTINCT neighbourhood_key),
    CAST(MIN(neighbourhood_key) AS STRING),
    CAST(MAX(neighbourhood_key) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'neighbourhood_cleansed',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(neighbourhood_cleansed),
    COUNT(DISTINCT neighbourhood_cleansed),
    MIN(neighbourhood_cleansed),
    MAX(neighbourhood_cleansed)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'room_type_key',
    'int',
    COUNT(*),
    COUNT(*) - COUNT(room_type_key),
    COUNT(DISTINCT room_type_key),
    CAST(MIN(room_type_key) AS STRING),
    CAST(MAX(room_type_key) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'room_type',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(room_type),
    COUNT(DISTINCT room_type),
    MIN(room_type),
    MAX(room_type)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'price',
    'double',
    COUNT(*),
    COUNT(*) - COUNT(price),
    COUNT(DISTINCT price),
    CAST(MIN(price) AS STRING),
    CAST(MAX(price) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'accommodates',
    'int',
    COUNT(*),
    COUNT(*) - COUNT(accommodates),
    COUNT(DISTINCT accommodates),
    CAST(MIN(accommodates) AS STRING),
    CAST(MAX(accommodates) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'bedrooms',
    'double',
    COUNT(*),
    COUNT(*) - COUNT(bedrooms),
    COUNT(DISTINCT bedrooms),
    CAST(MIN(bedrooms) AS STRING),
    CAST(MAX(bedrooms) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'beds',
    'double',
    COUNT(*),
    COUNT(*) - COUNT(beds),
    COUNT(DISTINCT beds),
    CAST(MIN(beds) AS STRING),
    CAST(MAX(beds) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'availability_30',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(availability_30),
    COUNT(DISTINCT availability_30),
    MIN(availability_30),
    MAX(availability_30)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'availability_60',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(availability_60),
    COUNT(DISTINCT availability_60),
    MIN(availability_60),
    MAX(availability_60)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'availability_90',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(availability_90),
    COUNT(DISTINCT availability_90),
    MIN(availability_90),
    MAX(availability_90)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'availability_365',
    'int',
    COUNT(*),
    COUNT(*) - COUNT(availability_365),
    COUNT(DISTINCT availability_365),
    CAST(MIN(availability_365) AS STRING),
    CAST(MAX(availability_365) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'number_of_reviews',
    'int',
    COUNT(*),
    COUNT(*) - COUNT(number_of_reviews),
    COUNT(DISTINCT number_of_reviews),
    CAST(MIN(number_of_reviews) AS STRING),
    CAST(MAX(number_of_reviews) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'review_scores_rating',
    'double',
    COUNT(*),
    COUNT(*) - COUNT(review_scores_rating),
    COUNT(DISTINCT review_scores_rating),
    CAST(MIN(review_scores_rating) AS STRING),
    CAST(MAX(review_scores_rating) AS STRING)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'host_is_superhost',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(host_is_superhost),
    COUNT(DISTINCT host_is_superhost),
    MIN(host_is_superhost),
    MAX(host_is_superhost)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'instant_bookable',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(instant_bookable),
    COUNT(DISTINCT instant_bookable),
    MIN(instant_bookable),
    MAX(instant_bookable)
FROM workspace.default.fact_listing_dimensional

UNION ALL

SELECT
    'last_scraped',
    'string',
    COUNT(*),
    COUNT(*) - COUNT(last_scraped),
    COUNT(DISTINCT last_scraped),
    MIN(last_scraped),
    MAX(last_scraped)
FROM workspace.default.fact_listing_dimensional

ORDER BY atributo;
